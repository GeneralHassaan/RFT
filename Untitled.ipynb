# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/users/hassaanasif/desktop/WB.csv")

# %%
data.head()
# Out:
#                   country_name country_code      1961      1962      1963  \
# 0                        Aruba          ABW  2.179059  1.548572  1.389337
# 1  Africa Eastern and Southern          AFE  2.660180  2.732633  2.753248
# 2                  Afghanistan          AFG  1.925952  2.014879  2.078997
# 3   Africa Western and Central          AFW  2.115789  2.145723  2.190827
# 4                       Angola          AGO  1.558355  1.460738  1.410425
#
#        1964      1965      1966      1967      1968  ...      2013      2014  \
# 0  1.215721  1.032841  0.862184  0.388847 -0.085719  ...  0.749301  0.691615
# 1  2.806915  2.840787  2.813609  2.830505  2.881589  ...  2.780207  2.774990
# 2  2.139651  2.216007  2.253524  2.292638  2.347351  ...  3.466788  3.657576
# 3  2.211360  2.242567  2.272816  2.275721  2.295953  ...  2.761839  2.750731
# 4  1.301745  1.111041  0.875806  0.696698  0.695985  ...  3.735525  3.684429
#
# ...

# %%
data.columns
# Out:
# Index(['country_name', 'country_code', '1961', '1962', '1963', '1964', '1965',
#        '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974',
#        '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983',
#        '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992',
#        '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001',
#        '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010',
#        '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019',
#        '2020', '2021', '2022'],
#       dtype='object')

# %%
data.tail(5)
# Out:
#             country_name country_code      1961      1962      1963      1964  \
# 260  Upper middle income          UMC  0.491945  1.533751  2.446167  2.367507
# 261        Middle income          MIC  1.314382  1.912035  2.432857  2.387584
# 262  Lower middle income          LMC  2.405341  2.404450  2.415678  2.413504
# 263           Low income          LIC  2.336207  2.374212  2.409516  2.472147
# 264          High income          HIC  1.253649  1.266471  1.238717  1.220550
#
#          1965      1966      1967      1968  ...      2013      2014  \
# 260  2.365031  2.518137  2.406522  2.426872  ...  0.869012  0.832036
# 261  2.370598  2.437824  2.370731  2.389117  ...  1.244264  1.223607
# 262  2.377783  2.334197  2.324467  2.340275  ...  1.597908  1.589985
# 263  2.522514  2.534040  2.597076  2.657151  ...  2.561679  2.503727
# 264  1.169416  1.099563  1.043884  1.021250  ...  0.568463  0.572885
#
#          2015      2016      2017      2018      2019      2020      2021  \
# ...

# %%
data.isnull().sum()
# Out:
# country_name    0
# country_code    0
# 1961            1
# 1962            1
# 1963            1
#                ..
# 2018            0
# 2019            0
# 2020            0
# 2021            0
# 2022            1
# Length: 64, dtype: int64

# %% [markdown]
# # ScatterPlots

# %%
sns.relplot(x="2020" , y="2022" , data=data)

# %%
sns.relplot(x="2010" , y ="2020" , kind ='Line' , data=data)
